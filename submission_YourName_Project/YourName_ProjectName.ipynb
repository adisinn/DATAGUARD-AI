# %% [markdown]
# # DataGuard AI — Project Notebook
#
# This notebook demonstrates basic usage of the DataGuard AI demo project: loading sample datasets, running a quick profile on `customer_profiles_enriched.csv`, and showing sample profiling output.

# %%
# Cell 1: Imports
import pandas as pd
from pathlib import Path

DATA_DIR = Path('sample_data')
df = pd.read_csv(DATA_DIR / 'customer_profiles_enriched.csv')
df.head()

# %%
# Cell 2: Simple profile summary
df.describe(include='all').T

# %%
# Cell 3: Save a small report
report = df.describe(include='all').T
report.to_csv('submission_profile_summary.csv')
print('Saved submission_profile_summary.csv')
